# %%
import joblib
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("Chocolate_Sales.csv")
df.head()
# Out:
#      Sales Person    Country              Product        Date      Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022   $5,320.00
# 1     Van Tuxwell      India        85% Dark Bars  01/08/2022   $7,896.00
# 2    Gigi Bohling      India  Peanut Butter Cubes  07/07/2022   $4,501.00
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022  $12,726.00
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022  $13,685.00
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3282 entries, 0 to 3281
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   3282 non-null   object
#  1   Country        3282 non-null   object
#  2   Product        3282 non-null   object
#  3   Date           3282 non-null   object
#  4   Amount         3282 non-null   object
#  5   Boxes Shipped  3282 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 154.0+ KB

# %%
df['Amount'].unique()
# Out:
# array(['$5,320.00', '$7,896.00', '$4,501.00', ..., '$616.09', '$2,504.62',
#        '$5,915.87'], shape=(3013,), dtype=object)

# %%
df['Amount'] = (df['Amount'].astype(str)
                .str.replace(",", "", regex=False)
                .str.replace("$", "", regex=False)
                .str.strip())
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')

# %%
df['Amount'].dtype
# Out:
# dtype('float64')

# %%
df['Amount']
# Out:
# 0        5320.00
# 1        7896.00
# 2        4501.00
# 3       12726.00
# 4       13685.00
#           ...
# 3277     5303.58
# 3278     7339.32
# 3279      616.09
# 3280     2504.62
# 3281     5915.87
# Name: Amount, Length: 3282, dtype: float64

# %%
df.isna().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount           0
# Boxes Shipped    0
# dtype: int64

# %%
df["Date"] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df = df.dropna(subset=["Date"])

# %%
df["Date"]
# Out:
# 0      2022-04-01
# 1      2022-01-08
# 2      2022-07-07
# 5      2022-06-06
# 9      2022-04-07
#           ...
# 3266   2024-12-08
# 3267   2024-11-03
# 3269   2024-12-05
# 3270   2024-12-01
# 3278   2024-07-06
# Name: Date, Length: 1290, dtype: datetime64[ns]

# %%
df['Date'].isna().sum()
# Out:
# np.int64(0)

# %%
threshold = df["Amount"].quantile(0.70)
df['Big_Sale'] = (df['Amount'] >= threshold).astype(int)

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-04-01  5320.0
# 1     Van Tuxwell      India        85% Dark Bars 2022-01-08  7896.0
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07  4501.0
# 5     Van Tuxwell      India   Smooth Sliky Salty 2022-06-06  5376.0
# 9     Brien Boise  Australia      99% Dark & Pure 2022-04-07  2835.0
#
#    Boxes Shipped  Big_Sale
# 0            180         0
# 1             94         1
# 2             91         0
# 5             38         0
# 9            102         0

# %%
df = df.drop('Amount', axis=1)

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date  Boxes Shipped  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-04-01            180
# 1     Van Tuxwell      India        85% Dark Bars 2022-01-08             94
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07             91
# 5     Van Tuxwell      India   Smooth Sliky Salty 2022-06-06             38
# 9     Brien Boise  Australia      99% Dark & Pure 2022-04-07            102
#
#    Big_Sale
# 0         0
# 1         1
# 2         0
# 5         0
# 9         0

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Month'] = df['Date'].dt.month
df['Weekday'] = df['Date'].dt.weekday

# %%
df = df.drop("Date", axis=1)

# %%
df.head()
# Out:
#      Sales Person    Country              Product  Boxes Shipped  Big_Sale  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco            180         0
# 1     Van Tuxwell      India        85% Dark Bars             94         1
# 2    Gigi Bohling      India  Peanut Butter Cubes             91         0
# 5     Van Tuxwell      India   Smooth Sliky Salty             38         0
# 9     Brien Boise  Australia      99% Dark & Pure            102         0
#
#    Month  Weekday
# 0      4        4
# 1      1        5
# 2      7        3
# 5      6        0
# 9      4        3

# %%
df = pd.get_dummies(df, columns=['Sales Person', 'Country', 'Product'], drop_first=True)

# %%
df.head()
# Out:
#    Boxes Shipped  Big_Sale  Month  Weekday  Sales Person_Barr Faughny  \
# 0            180         0      4        4                      False
# 1             94         1      1        5                      False
# 2             91         0      7        3                      False
# 5             38         0      6        0                      False
# 9            102         0      4        3                      False
#
#    Sales Person_Beverie Moffet  Sales Person_Brien Boise  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 5                        False                     False
# 9                        False                      True
#
#    Sales Person_Camilla Castle  Sales Person_Ches Bonnell  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 5                        False                      False
# 9                        False                      False
#
#    Sales Person_Curtice Advani  ...  Product_Manuka Honey Choco  \
# 0                        False  ...                       False
# 1                        False  ...                       False
# 2                        False  ...                       False
# 5                        False  ...                       False
# 9                        False  ...                       False
#
#    Product_Milk Bars  Product_Mint Chip Choco  Product_Orange Choco  \
# 0              False                     True                 False
# 1              False                    False                 False
# 2              False                    False                 False
# 5              False                    False                 False
# 9              False                    False                 False
#
#    Product_Organic Choco Syrup  Product_Peanut Butter Cubes  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                         True
# 5                        False                        False
# 9                        False                        False
#
#    Product_Raspberry Choco  Product_Smooth Sliky Salty  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 5                    False                        True
# 9                    False                       False
#
#    Product_Spicy Special Slims  Product_White Choc
# 0                        False               False
# 1                        False               False
# 2                        False               False
# 5                        False               False
# 9                        False               False
#
# [5 rows x 54 columns]

# %%
X = df.drop('Big_Sale', axis=1)

joblib.dump(X.columns.tolist(), "feature_names.pkl")
y = df['Big_Sale']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

print('Accuracy: ', accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:  0.686046511627907
#               precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79       174
#            1       0.54      0.26      0.35        84
#
#     accuracy                           0.69       258
#    macro avg       0.63      0.58      0.57       258
# weighted avg       0.66      0.69      0.65       258

# %%
joblib.dump(model, "big_sale_model.pkl")
# Out:
# ['big_sale_model.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
